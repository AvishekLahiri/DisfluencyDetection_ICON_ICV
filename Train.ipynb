# %%
import pandas as pd
import numpy as np
import csv
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %%
from pathlib import Path
import re
import operator as op
from collections import Counter


def read_file(file_path, new_filename):
    file_path = Path(file_path)
    new_file = open(new_filename, 'w')
    raw_text = file_path.read_text().strip()
    raw_docs = re.split(r'\n\t?\n', raw_text)
    token_docs = []
    tag_docs = []

    filler = []
    pet = []
    ctr=1
    for doc in raw_docs:
        tokens = []
        tags = []
        repeat = 0
        for line in doc.split('\n'):
            if len(line.strip()) == 0:
                continue
            try: 
                token, tag = line.split('\t')
            except:
                continue
            if tag[tag.find('-')+1:] == 'filler_R':
                filler.append(token)
                tag = 'O'
            elif tag[tag.find('-')+1:] == 'pet_R':
                pet.append(token)
                tag = 'O'
            elif tag[tag.find('-')+1:] == 'repeat_R':
                tag = 'O'
                repeat = 1
            if repeat == 1 and tag[tag.find('-')+1:] == 'Alteration':
                tag = 'O'
            tokens.append(token)
            tags.append(tag)
            new_file.write("Sentence: "+str(ctr)+'\t'+token+'\t'+tag+'\n')

        token_docs.append(tokens)
        tag_docs.append(tags)
        ctr=ctr+1
        new_file.write('\n')

    print(len(filler), len(set(filler)), set(filler))
    print(len(pet), len(set(pet)), set(pet))

    return filler, pet

# %%
filler_train, pet_train = read_file('/path/to/train/data/', 'train.tsv')
dev_texts, pet_test = read_file('/path/to/dev/data/', 'dev.tsv')
# Out:
# 673 43 {'హే', 'హహ...', 'ఎస్', 'విధంగా', 'హ..', 'నా', 'య', 'అదేవిధంగా', '...', 'సీ', ',', 'నో', 'ఆ.', 'హహహ', 'లాట్సాప్', 'ఇది', 'హ్మ్మ్', '..', 'ఏంటి', 'హహ', 'ఈ', '.', 'అంటే', 'సో', 'అసలు', 'ఆహ్', 'అది', 'హ.', 'ఓ', 'హహ.', 'యు', 'ఉహ్', 'ఒక', 'లైక్', 'ఏ', 'ఆ', 'ఉ', 'ప్చ్', '....', 'సొ', 'అదే', 'ఎ', 'హ'}
# 968 30 {'మరి', 'దిస్', 'మీకు', 'నొ', 'య', 'ఏంటంటే', ',', 'కెన్', 'నో', 'మీక', 'టే', 'సి', '..', '.', 'రైట్', 'దట్', 'సో', 'అసలు', 'సరే', 'అది', 'హ.', 'నేను', 'యు', 'ఐ', 'ఆ', 'చూసిగా', 'అం', 'మీన్', 'బట్', 'యా'}
# 62 4 {'హ్మ్మ్', 'ప్చ్', 'ఆహ్', 'ఉహ్'}
# 125 6 {'టే', 'మరి', 'సరే', 'అది', 'అం', 'అసలు'}

# %%
colnames=['Sentence #','Word', 'Tag']
train = pd.read_csv('train.tsv', delimiter='\t', encoding = "utf-8", quoting=csv.QUOTE_NONE, names=colnames, header=None)
dev = pd.read_csv('dev.tsv', delimiter='\t', encoding = "utf-8", quoting=csv.QUOTE_NONE, names=colnames, header=None)

# %%
train = train.fillna(method='ffill')
dev = dev.fillna(method='ffill')

# %%
frames = [train, dev]
df = pd.concat(frames)

# %%
df.groupby('Tag').size().reset_index(name='counts')
# Out:
#             Tag  counts
# 0  B-Alteration    1408
# 1      B-edit_R     314
# 2     B-false_R     345
# 3    B-repair_R     261
# 4  I-Alteration     180
# 5      I-edit_R     419
# 6     I-false_R     564
# 7    I-repair_R     859
# 8             O   52767

# %%
X = df.drop('Tag', axis=1)

# %%
v = DictVectorizer(sparse=False)
X = v.fit_transform(X.to_dict('records'))

# %%
y = df.Tag.values

# %%
classes = np.unique(y)
classes = classes.tolist()
classes
# Out:
# ['B-Alteration',
#  'B-edit_R',
#  'B-false_R',
#  'B-repair_R',
#  'I-Alteration',
#  'I-edit_R',
#  'I-false_R',
#  'I-repair_R',
#  'O']

# %%
X.shape, y.shape
# Out:
# ((57117, 19026), (57117,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=0)

# %%
new_classes = classes.copy()
new_classes.remove('O')
new_classes
# Out:
# ['B-Alteration',
#  'B-edit_R',
#  'B-false_R',
#  'B-repair_R',
#  'I-Alteration',
#  'I-edit_R',
#  'I-false_R',
#  'I-repair_R']

# %%
nb = MultinomialNB(alpha=0.01)
nb.partial_fit(X_train, y_train, classes)
# Out:
# MultinomialNB(alpha=0.01)

# %%
print(classification_report(y_pred=nb.predict(X_test), y_true=y_test, labels = new_classes))
# Out:
#               precision    recall  f1-score   support
#
# B-Alteration       0.60      0.54      0.57       466
#     B-edit_R       0.08      0.14      0.10       104
#    B-false_R       0.00      0.00      0.00       127
#   B-repair_R       0.00      0.00      0.00        91
# I-Alteration       0.07      0.12      0.09        68
#     I-edit_R       0.29      0.36      0.32       146
#    I-false_R       0.09      0.16      0.12       170
#   I-repair_R       0.48      0.55      0.52       285
#
#    micro avg       0.29      0.35      0.32      1457
#    macro avg       0.20      0.24      0.21      1457
# weighted avg       0.34      0.35      0.34      1457

# %%
def find_repeated_sequences(s):
    match = re.findall(r'((\b.+?\b)(?:\s\2)+)', s)
    return [(m[1], int((len(m[0]) + 1) / (len(m[1]) + 1))) for m in match]

# %%
def read_test_file(file_path, new_filename):
    file_path = Path(file_path)
    new_file = open(new_filename, 'w')
    raw_text = file_path.read_text().strip()
    raw_docs = re.split(r'\n\t?\n', raw_text)
    token_docs = {}
    tag_docs = []
    ctr=1
    for doc in raw_docs:
        tokens = ''
        tags = []
        repeat = 0
        for line in doc.split('\n'):
            if len(line.strip()) == 0:
                continue
            tokens = tokens + line + ' '
            new_file.write("Sentence: "+str(ctr)+'\t'+line+'\n')
            if line == '.':
                
                #print(tokens)
                r = find_repeated_sequences(tokens)                
                tokens = ''
                token_docs["Sentence: "+str(ctr)] = r
                ctr=ctr+1
        new_file.write('\n')
        
    return token_docs

# %%
labs= read_test_file('/path/to/test/data/', 'test.tsv')

# %%
test = pd.read_csv('test.tsv', delimiter='\t', encoding = "utf-8", quoting=csv.QUOTE_NONE, names=['Sentence #','Word'], header=None)

# %%
test = test.fillna(method='ffill')

# %%
X_t = v.transform(test.to_dict('records'))

# %%
test.to_dict('records')
# Out:
# [{'Sentence #': 'Sentence: 1', 'Word': 'నీట్'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'జాతీయ'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'ర్యాంకుల్లో'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'రాష్ట్రాల'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'విద్యార్థులు'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'సత్తా'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'చాటారు'},
#  {'Sentence #': 'Sentence: 1', 'Word': ','},
#  {'Sentence #': 'Sentence: 1', 'Word': 'తెలంగాణ'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'విద్యార్థిని'},
#  {'Sentence #': 'Sentence: 1', 'Word': '""""'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'జి'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'మాధురి'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'రెడ్డి'},
#  {'Sentence #': 'Sentence: 1', 'Word': '""""'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'ఆరు'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'వందల'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'తొంభై'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'ఐదు'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'మార్కులతో'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'ఏడవ'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'ర్యాంకు'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'సాధించగా'},
#  {'Sentence #': 'Sentence: 1', 'Word': ','},
#  {'Sentence #': 'Sentence: 1', 'Word': 'ఆరు'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'వందల'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'తొంభై'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'మార్కులతో'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'ఏపీ'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'విద్యార్థిని'},
#  {'Sentence #': 'Sentence: 1', 'Word': '""""'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'ఖురేషి'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'అస్రా'},
#  {'Sentence #': 'Sentence: 1', 'Word': '""""'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'పదహారొవ'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'స్థానంలో'},
#  {'Sentence #': 'Sentence: 1', 'Word': 'నిలిచింది'},
#  {'Sentence #': 'Sentence: 1', 'Word': '.'},
#  {'Sentence #': 'Sentence: 2', 'Word': '""'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'నిరంతర'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'కృషి'},
#  {'Sentence #': 'Sentence: 2', 'Word': ','},
#  {'Sentence #': 'Sentence: 2', 'Word': 'శ్రమ'},
#  {'Sentence #': 'Sentence: 2', 'Word': ','},
#  {'Sentence #': 'Sentence: 2', 'Word': 'కళాశాల'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'యాజమాన్యం'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'వల్లే'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'విజయం'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'సాధ్యమైంది'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'అంటున్న'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'విజేతలతో'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'ఈటీవీ'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'ప్రత్యేక'},
#  {'Sentence #': 'Sentence: 2', 'Word': 'ముఖాముఖి'},
#  {'Sentence #': 'Sentence: 2', 'Word': '.'},
#  {'Sentence #': 'Sentence: 3', 'Word': '""'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'వైద్య'},
#  {'Sentence #': 'Sentence: 3', 'Word': ','},
#  {'Sentence #': 'Sentence: 3', 'Word': 'విద్య'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'కోర్సుల్లో'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'ప్రవేశాల'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'కోసం'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'నిర్వహించినటువంటి'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'నీట్'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'విద్యార్థులు'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'ప్రతిభ'},
#  {'Sentence #': 'Sentence: 3', 'Word': 'చాటారు'},
#  {'Sentence #': 'Sentence: 3', 'Word': '.'},
#  {'Sentence #': 'Sentence: 4', 'Word': '""'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'అదే'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'విధంగా'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'అంటారు'},
#  {'Sentence #': 'Sentence: 4', 'Word': ','},
#  {'Sentence #': 'Sentence: 4', 'Word': 'వివిధ'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'వంద'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'లోపు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'ర్యాంకులు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'సాధించారు'},
#  {'Sentence #': 'Sentence: 4', 'Word': ','},
#  {'Sentence #': 'Sentence: 4', 'Word': 'అదేవిధంగా'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'ఇరవై'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'లోపు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'ర్యాంకుల్లో'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'రెండు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'ర్యాంకులు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'విద్యార్థులు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'కైవసం'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'చేసుకున్నారు'},
#  {'Sentence #': 'Sentence: 4', 'Word': ','},
#  {'Sentence #': 'Sentence: 4', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'విద్యార్థులతో'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'పాటు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'ఈసారి'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'రాష్ట్రాలకు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'విద్యార్థులు'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'ఎలాంటి'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'ప్రతిభను'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'ప్రదర్శించారని'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'అడిగి'},
#  {'Sentence #': 'Sentence: 4', 'Word': 'తెలుసుకుందాం'},
#  {'Sentence #': 'Sentence: 4', 'Word': '.'},
#  {'Sentence #': 'Sentence: 5', 'Word': '""'},
#  {'Sentence #': 'Sentence: 5', 'Word': 'కంగ్రాచులేషన్స్'},
#  {'Sentence #': 'Sentence: 5', 'Word': '!'},
#  {'Sentence #': 'Sentence: 5', 'Word': 'మీకు'},
#  {'Sentence #': 'Sentence: 5', 'Word': 'ప్రధానంగా'},
#  {'Sentence #': 'Sentence: 5', 'Word': '.'},
#  {'Sentence #': 'Sentence: 6', 'Word': '""'},
#  {'Sentence #': 'Sentence: 6', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 6', 'Word': 'జాతీయ'},
#  {'Sentence #': 'Sentence: 6', 'Word': 'స్థాయిలో'},
#  {'Sentence #': 'Sentence: 6', 'Word': 'ఏడవ'},
#  {'Sentence #': 'Sentence: 6', 'Word': 'ర్యాంకు'},
#  {'Sentence #': 'Sentence: 6', 'Word': ','},
#  {'Sentence #': 'Sentence: 6', 'Word': 'బాలికల'},
#  {'Sentence #': 'Sentence: 6', 'Word': 'కేటగిరీలో'},
#  {'Sentence #': 'Sentence: 6', 'Word': 'మొదటి'},
#  {'Sentence #': 'Sentence: 6', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 6', 'Word': 'సాధించినందుకు'},
#  {'Sentence #': 'Sentence: 6', 'Word': '.'},
#  {'Sentence #': 'Sentence: 7', 'Word': '""'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'అయితే'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'ఈ'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'విజయాన్ని'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'ఏ'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'విధంగా'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'సాధించారు'},
#  {'Sentence #': 'Sentence: 7', 'Word': '?'},
#  {'Sentence #': 'Sentence: 7', 'Word': '""'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'ప్రధానంగా'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'ముఖ్యంగా'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'మీ'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'పేరెంట్స్'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'బ్యాక్'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'గ్రౌండ్'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'ఏమిటి'},
#  {'Sentence #': 'Sentence: 7', 'Word': '?'},
#  {'Sentence #': 'Sentence: 7', 'Word': '""'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'మా'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'డాడీ'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'ఈస్'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'ఎ'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'సాఫ్ట్'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'వేర్'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'ఇంజినీర్'},
#  {'Sentence #': 'Sentence: 7', 'Word': ','},
#  {'Sentence #': 'Sentence: 7', 'Word': 'మమ్మీ'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'హౌస్'},
#  {'Sentence #': 'Sentence: 7', 'Word': 'వైఫ్'},
#  {'Sentence #': 'Sentence: 7', 'Word': '.'},
#  {'Sentence #': 'Sentence: 8', 'Word': '""'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'మా'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'టీచర్స్'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'వాళ్ళు'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'చూపిన'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'మా'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'పైన'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'ఇంటరెస్ట్'},
#  {'Sentence #': 'Sentence: 8', 'Word': ','},
#  {'Sentence #': 'Sentence: 8', 'Word': 'ఇంకా'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'వాళ్ళు'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'మమ్మల్ని'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'మోటివేట్'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'చేసి'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'దానికి'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'మేము'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'మాకు'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'కాన్ఫిడెన్స్'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'పెరిగి'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'మేము'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'వర్క్'},
#  {'Sentence #': 'Sentence: 8', 'Word': 'చేశాము'},
#  {'Sentence #': 'Sentence: 8', 'Word': '.'},
#  {'Sentence #': 'Sentence: 9', 'Word': '""'},
#  {'Sentence #': 'Sentence: 9', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 9', 'Word': 'ఎగ్జామ్స్'},
#  {'Sentence #': 'Sentence: 9', 'Word': 'కండక్ట్'},
#  {'Sentence #': 'Sentence: 9', 'Word': 'చేశారు'},
#  {'Sentence #': 'Sentence: 9', 'Word': ','},
#  {'Sentence #': 'Sentence: 9', 'Word': 'మేం'},
#  {'Sentence #': 'Sentence: 9', 'Word': 'చేసిన'},
#  {'Sentence #': 'Sentence: 9', 'Word': 'తప్పుల్ని'},
#  {'Sentence #': 'Sentence: 9', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 9', 'Word': 'కరెక్ట్'},
#  {'Sentence #': 'Sentence: 9', 'Word': 'చేసుకున్నాము'},
#  {'Sentence #': 'Sentence: 9', 'Word': '.'},
#  {'Sentence #': 'Sentence: 10', 'Word': '""'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'లాస్ట్'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'ఫ్యూ'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'డేస్'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'ఏం'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'లాస్ట్'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'ఫ్యూ'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'డేస్'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'ఎగ్జామ్స్'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'కండక్ట్'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'చేయడం'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'వల్ల'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'చిన్న'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'చిన్న'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'టాపిక్స్'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'మేం'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'వీక్'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'గా'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'ఉన్నవి'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'కవర్'},
#  {'Sentence #': 'Sentence: 10', 'Word': 'చేసుకోగలిగాము'},
#  {'Sentence #': 'Sentence: 10', 'Word': '.'},
#  {'Sentence #': 'Sentence: 11', 'Word': '""'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'డాక్టర్'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'కావాలన్న'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'ఆలోచన'},
#  {'Sentence #': 'Sentence: 11', 'Word': ','},
#  {'Sentence #': 'Sentence: 11', 'Word': 'కోరిక'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'ముందు'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'ఎప్పుడు'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'మొదలైంది'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'దానికి'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'సంబంధించి'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'ప్రిపరేషన్'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'ఏ'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'విధంగా'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'అవుతూ'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'వచ్చావ్'},
#  {'Sentence #': 'Sentence: 11', 'Word': '?'},
#  {'Sentence #': 'Sentence: 11', 'Word': '""'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'నాకు'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'నైన్త్'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 11', 'Word': 'అవ్వాలనిపించింది'},
#  {'Sentence #': 'Sentence: 11', 'Word': '.'},
#  {'Sentence #': 'Sentence: 12', 'Word': '""'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'సో'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'అప్పడి'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'నుంచి'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'నేను'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'నారాయణ'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'మేడి'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'స్పార్క్'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'ప్రోగ్రామ్'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'జాయిన్'},
#  {'Sentence #': 'Sentence: 12', 'Word': 'అయ్యాను'},
#  {'Sentence #': 'Sentence: 12', 'Word': '.'},
#  {'Sentence #': 'Sentence: 13', 'Word': '""'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'ప్రోగ్రాం'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'బేసిక్'},
#  {'Sentence #': 'Sentence: 13', 'Word': ','},
#  {'Sentence #': 'Sentence: 13', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'ప్రోగ్రాం'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'జాయిన్'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'అవ్వడం'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'వల్ల'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'కొన్ని'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'బేసిక్స్'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'తెలుసుకొని'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'అవి'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'హెల్ప్'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'చేశాయి'},
#  {'Sentence #': 'Sentence: 13', 'Word': ','},
#  {'Sentence #': 'Sentence: 13', 'Word': 'నా'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'ఇంటర్'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'ఫస్ట్'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'అండ్'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'ఇయర్'},
#  {'Sentence #': 'Sentence: 13', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 13', 'Word': '.'},
#  {'Sentence #': 'Sentence: 14', 'Word': '""'},
#  {'Sentence #': 'Sentence: 14', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 14', 'Word': 'నీట్'},
#  {'Sentence #': 'Sentence: 14', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 14', 'Word': 'జాతీయ'},
#  {'Sentence #': 'Sentence: 14', 'Word': 'స్థాయిలో'},
#  {'Sentence #': 'Sentence: 14', 'Word': 'పోటీ'},
#  {'Sentence #': 'Sentence: 14', 'Word': 'ఉంటుంది'},
#  {'Sentence #': 'Sentence: 14', 'Word': '.'},
#  {'Sentence #': 'Sentence: 15', 'Word': '""'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'అదేవిధంగా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'మైనస్'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'మార్క్స్'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'కూడా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'ఉంటాయి'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'కాబట్టి'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'ఇవన్నీ'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'ఏమన్నా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'ఒత్తిడిగా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'కల్పించాయా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'ఎపుడైనా'},
#  {'Sentence #': 'Sentence: 15', 'Word': '?'},
#  {'Sentence #': 'Sentence: 15', 'Word': '""'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'మా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'డీన్స్'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'ఇంకా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'మా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'టీచర్స్'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'చిన్న'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'చిన్న'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'కాన్సెప్ట్స్'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'ని'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'కూడా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'క్లారిఫై'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'చేసి'},
#  {'Sentence #': 'Sentence: 15', 'Word': ','},
#  {'Sentence #': 'Sentence: 15', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'డీటెయిల్'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'గా'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'ఎక్స్ప్లెయిన్'},
#  {'Sentence #': 'Sentence: 15', 'Word': 'చేశారు'},
#  {'Sentence #': 'Sentence: 15', 'Word': '.'},
#  {'Sentence #': 'Sentence: 16', 'Word': '""'},
#  {'Sentence #': 'Sentence: 16', 'Word': 'మాకు'},
#  {'Sentence #': 'Sentence: 16', 'Word': 'ఏ'},
#  {'Sentence #': 'Sentence: 16', 'Word': 'స్ట్రెస్'},
#  {'Sentence #': 'Sentence: 16', 'Word': 'లేకుండా'},
#  {'Sentence #': 'Sentence: 16', 'Word': 'మంచిగా'},
#  {'Sentence #': 'Sentence: 16', 'Word': 'కౌన్సిలింగ్'},
#  {'Sentence #': 'Sentence: 16', 'Word': 'కూడా'},
#  {'Sentence #': 'Sentence: 16', 'Word': 'ఇచ్చేవాళ్ళు'},
#  {'Sentence #': 'Sentence: 16', 'Word': '.'},
#  {'Sentence #': 'Sentence: 17', 'Word': '""'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'నీట్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'రావాలంటే'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'ఇక'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'ఆటపాటలు'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'అవన్నీ'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'వదిలేసి'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'పూర్తిగా'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'చదివుకే'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'అంకితం'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'కావాలంటారు'},
#  {'Sentence #': 'Sentence: 17', 'Word': ','},
#  {'Sentence #': 'Sentence: 17', 'Word': 'నిజమేనా'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'అది'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'ఎన్ని'},
#  {'Sentence #': 'Sentence: 17', 'Word': ','},
#  {'Sentence #': 'Sentence: 17', 'Word': 'ఎన్ని'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'గంటలు'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'చదివే'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'వారు'},
#  {'Sentence #': 'Sentence: 17', 'Word': '?'},
#  {'Sentence #': 'Sentence: 17', 'Word': '""'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'క్లాసెస్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'కాకుండా'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'టెన్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'టు'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'ట్వెల్వ్'},
#  {'Sentence #': 'Sentence: 17', 'Word': ','},
#  {'Sentence #': 'Sentence: 17', 'Word': 'మార్నింగ్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'సెవెన్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'టు'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'నైన్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'టెన్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'వరకు'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'ఉండేదాన్ని'},
#  {'Sentence #': 'Sentence: 17', 'Word': ','},
#  {'Sentence #': 'Sentence: 17', 'Word': 'టెన్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'టెన్'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'థర్టీ'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'దాకా'},
#  {'Sentence #': 'Sentence: 17', 'Word': ','},
#  {'Sentence #': 'Sentence: 17', 'Word': 'అప్పుడు'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'మొత్తం'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'చదువుకుంటూ'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'ఉండే'},
#  {'Sentence #': 'Sentence: 17', 'Word': 'వాళ్ళం'},
#  {'Sentence #': 'Sentence: 17', 'Word': '.'},
#  {'Sentence #': 'Sentence: 18', 'Word': '""'},
#  {'Sentence #': 'Sentence: 18', 'Word': 'ఇప్పుడు'},
#  {'Sentence #': 'Sentence: 18', 'Word': 'ప్రస్తుతం'},
#  {'Sentence #': 'Sentence: 18', 'Word': 'గోల్'},
#  {'Sentence #': 'Sentence: 18', 'Word': 'ఏంటి'},
#  {'Sentence #': 'Sentence: 18', 'Word': '?'},
#  {'Sentence #': 'Sentence: 18', 'Word': '""'},
#  {'Sentence #': 'Sentence: 18', 'Word': 'ఎయిమ్స్'},
#  {'Sentence #': 'Sentence: 18', 'Word': 'వెళ్లి'},
#  {'Sentence #': 'Sentence: 18', 'Word': '.'},
#  {'Sentence #': 'Sentence: 19', 'Word': '""'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'అసలు'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'చెప్పండి'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'నీకు'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'మొత్తం'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ఎన్ని'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'మార్క్స్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'వచ్చాయి'},
#  {'Sentence #': 'Sentence: 19', 'Word': ','},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ప్రస్తుతం'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'నీ'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ఎంటి'},
#  {'Sentence #': 'Sentence: 19', 'Word': '?'},
#  {'Sentence #': 'Sentence: 19', 'Word': '""'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'నాకు'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'సిక్స్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'నైంటీ'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'మార్క్స్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'వచ్చాయి'},
#  {'Sentence #': 'Sentence: 19', 'Word': ','},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ఆల్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ఇండియా'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'సిక్స్టీన్త్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 19', 'Word': ','},
#  {'Sentence #': 'Sentence: 19', 'Word': 'కేటగిరీ'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'వచ్చింది'},
#  {'Sentence #': 'Sentence: 19', 'Word': ','},
#  {'Sentence #': 'Sentence: 19', 'Word': 'సౌత్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ఇండియా'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 19', 'Word': ','},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ఆంధ్ర'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ఫస్ట్'},
#  {'Sentence #': 'Sentence: 19', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 19', 'Word': '.'},
#  {'Sentence #': 'Sentence: 20', 'Word': '""'},
#  {'Sentence #': 'Sentence: 20', 'Word': 'నారాయణ'},
#  {'Sentence #': 'Sentence: 20', 'Word': 'మాదాపూర్'},
#  {'Sentence #': 'Sentence: 20', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 20', 'Word': 'ఎయిత్'},
#  {'Sentence #': 'Sentence: 20', 'Word': ','},
#  {'Sentence #': 'Sentence: 20', 'Word': 'నైన్త్'},
#  {'Sentence #': 'Sentence: 20', 'Word': 'క్లాస్'},
#  {'Sentence #': 'Sentence: 20', 'Word': 'నుంచి'},
#  {'Sentence #': 'Sentence: 20', 'Word': 'చదువుతున్నాను'},
#  {'Sentence #': 'Sentence: 20', 'Word': '.'},
#  {'Sentence #': 'Sentence: 21', 'Word': '""'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'నైన్త్'},
#  {'Sentence #': 'Sentence: 21', 'Word': ','},
#  {'Sentence #': 'Sentence: 21', 'Word': 'టెన్త్'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'నా'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'మెడిస్పార్క్'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'ప్రోగ్రాం'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'జరిగింది'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'మాకు'},
#  {'Sentence #': 'Sentence: 21', 'Word': ','},
#  {'Sentence #': 'Sentence: 21', 'Word': 'అక్కడ'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'బేసిక్స్'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'బాగా'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'ప్రొవైడ్'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'చేశారు'},
#  {'Sentence #': 'Sentence: 21', 'Word': ','},
#  {'Sentence #': 'Sentence: 21', 'Word': 'సో'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'కాన్సెప్ట్'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'మీద'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'బాగా'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'స్ట్రెంతేన్'},
#  {'Sentence #': 'Sentence: 21', 'Word': 'అయ్యాము'},
#  {'Sentence #': 'Sentence: 21', 'Word': '.'},
#  {'Sentence #': 'Sentence: 22', 'Word': '""'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'తర్వాత'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'ఫస్ట్'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'ఇయర్'},
#  {'Sentence #': 'Sentence: 22', 'Word': ','},
#  {'Sentence #': 'Sentence: 22', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'ఇయర్'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'ఎన్'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'ఫార్టీ'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'ప్రోగ్రాం'},
#  {'Sentence #': 'Sentence: 22', 'Word': ','},
#  {'Sentence #': 'Sentence: 22', 'Word': 'ఎన్'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'ఫార్టీ'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'ప్రోగ్రాం'},
#  {'Sentence #': 'Sentence: 22', 'Word': 'చేశారు'},
#  {'Sentence #': 'Sentence: 22', 'Word': '.'},
#  {'Sentence #': 'Sentence: 23', 'Word': '""'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'ఎన్'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'ఫార్టీ'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'ప్రోగ్రాం'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'మేం'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'నేర్చుకున్న'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'బేసిక్స్'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'బాగా'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'అప్లై'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'చేయగలిగాము'},
#  {'Sentence #': 'Sentence: 23', 'Word': ','},
#  {'Sentence #': 'Sentence: 23', 'Word': 'రివిజన్'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'టైమ్'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'ఎగ్జామ్స్'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'పెట్టడం'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'వల్ల'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'ఎగ్జామ్స్'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'మీద'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'భయం'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'ఏమి'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'అనిపియాలేదు'},
#  {'Sentence #': 'Sentence: 23', 'Word': ','},
#  {'Sentence #': 'Sentence: 23', 'Word': 'స్ట్రెస్'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'ఫ్రీ'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'గా'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'ఎగ్జామ్స్'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'ని'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'రాయగలిగాం'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'లాస్ట్'},
#  {'Sentence #': 'Sentence: 23', 'Word': 'కి'},
#  {'Sentence #': 'Sentence: 23', 'Word': '.'},
#  {'Sentence #': 'Sentence: 24', 'Word': '""'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'పేరెంట్స్'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'బ్యాక్'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'గ్రౌండ్'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'ఏమిటి'},
#  {'Sentence #': 'Sentence: 24', 'Word': '?'},
#  {'Sentence #': 'Sentence: 24', 'Word': '""'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'మా'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'డాడీ'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'ఒక'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'బిజినెస్'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'చేస్తారు'},
#  {'Sentence #': 'Sentence: 24', 'Word': ','},
#  {'Sentence #': 'Sentence: 24', 'Word': 'మా'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'మమ్మీ'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'హౌస్'},
#  {'Sentence #': 'Sentence: 24', 'Word': 'వైఫ్'},
#  {'Sentence #': 'Sentence: 24', 'Word': '.'},
#  {'Sentence #': 'Sentence: 25', 'Word': '""'},
#  {'Sentence #': 'Sentence: 25', 'Word': 'గోల్'},
#  {'Sentence #': 'Sentence: 25', 'Word': 'ఏంటి'},
#  {'Sentence #': 'Sentence: 25', 'Word': 'ఫ్యూచర్'},
#  {'Sentence #': 'Sentence: 25', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 25', 'Word': 'ఏం'},
#  {'Sentence #': 'Sentence: 25', 'Word': 'కావాలి'},
#  {'Sentence #': 'Sentence: 25', 'Word': '?'},
#  {'Sentence #': 'Sentence: 25', 'Word': '""'},
#  {'Sentence #': 'Sentence: 25', 'Word': 'ఎయిమ్స్'},
#  {'Sentence #': 'Sentence: 25', 'Word': 'కి'},
#  {'Sentence #': 'Sentence: 25', 'Word': 'వెళ్ళాలి'},
#  {'Sentence #': 'Sentence: 25', 'Word': '.'},
#  {'Sentence #': 'Sentence: 26', 'Word': '""'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'అదే'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'ప్రధానంగా'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'ఈసారి'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'విద్యార్థులు'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'ఎలాంటి'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'ప్రతిభను'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'సాధించారు'},
#  {'Sentence #': 'Sentence: 26', 'Word': '?'},
#  {'Sentence #': 'Sentence: 26', 'Word': '""'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'మరియు'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'ప్రస్తుతం'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'ఎన్ని'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'వైద్య'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'సీట్లు'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'ఉన్నాయి'},
#  {'Sentence #': 'Sentence: 26', 'Word': '?'},
#  {'Sentence #': 'Sentence: 26', 'Word': '""'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'వీటన్నిటిని'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'విషయాల్ని'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'నారాయణ'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'గ్రూప్'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'సంస్థల'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'మేనేజింగ్'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'డైరెక్టర్'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'సింధూర'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'గారిని'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'అడిగి'},
#  {'Sentence #': 'Sentence: 26', 'Word': 'తెలుసుకుందాం'},
#  {'Sentence #': 'Sentence: 26', 'Word': '.'},
#  {'Sentence #': 'Sentence: 27', 'Word': '""'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'సింధూర'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'గారు'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ప్రధానంగా'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 27', 'Word': ','},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఈసారి'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'విద్యార్థుల'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'లని'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఏ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'విధంగా'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'విశ్లేషించవచ్చు'},
#  {'Sentence #': 'Sentence: 27', 'Word': '?'},
#  {'Sentence #': 'Sentence: 27', 'Word': '""'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'మనము'},
#  {'Sentence #': 'Sentence: 27', 'Word': ','},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఓన్లీ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఓపెన్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'కేటగిరీ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ర్యాంక్స్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'తీసుకున్నట్లయితే'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'మాధురిస్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఆల్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఇండియా'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఓపెన్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'కేటగిరీ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'సెవెంత్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 27', 'Word': ','},
#  {'Sentence #': 'Sentence: 27', 'Word': 'అలాగే'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'అస్రా'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'సిక్స్టీన్త్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 27', 'Word': ','},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఫార్టీ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 27', 'Word': ','},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఫార్టీ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'సెవెన్'},
#  {'Sentence #': 'Sentence: 27', 'Word': ','},
#  {'Sentence #': 'Sentence: 27', 'Word': 'సిక్స్టీ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఫోర్'},
#  {'Sentence #': 'Sentence: 27', 'Word': ','},
#  {'Sentence #': 'Sentence: 27', 'Word': 'సిక్స్టీ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'టు'},
#  {'Sentence #': 'Sentence: 27', 'Word': ','},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఎయిటి'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'వన్'},
#  {'Sentence #': 'Sentence: 27', 'Word': ','},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఆల్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఇండియా'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'ఓపెన్'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'కేటగిరీలో'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'నారాయణ'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'నుంచి'},
#  {'Sentence #': 'Sentence: 27', 'Word': 'సాధించాం'},
#  {'Sentence #': 'Sentence: 27', 'Word': '.'},
#  {'Sentence #': 'Sentence: 28', 'Word': '""'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'అలాగే'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఈ'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'స్టూడెంట్స్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఆల్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఇండియా'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఓపెన్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'కేటగిరీలో'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'గర్ల్స్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఫస్ట్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 28', 'Word': ','},
#  {'Sentence #': 'Sentence: 28', 'Word': 'గర్ల్స్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 28', 'Word': ','},
#  {'Sentence #': 'Sentence: 28', 'Word': 'అలాగే'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'సౌత్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఇండియా'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఫస్ట్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 28', 'Word': ','},
#  {'Sentence #': 'Sentence: 28', 'Word': 'సౌత్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఇండియా'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 28', 'Word': ','},
#  {'Sentence #': 'Sentence: 28', 'Word': 'అలాగే'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'మాకు'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'తెలంగాణలో'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఫస్ట్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 28', 'Word': ','},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఆంధ్రప్రదేశ్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'నుంచి'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ఫస్ట్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'అండ్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 28', 'Word': ','},
#  {'Sentence #': 'Sentence: 28', 'Word': 'కర్ణాటకలో'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 28', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 28', 'Word': '.'},
#  {'Sentence #': 'Sentence: 29', 'Word': '""'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'పెట్టిన'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'ఇన్స్టిట్యూషన్స్'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'నాట్'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'ఓన్లీ'},
#  {'Sentence #': 'Sentence: 29', 'Word': ','},
#  {'Sentence #': 'Sentence: 29', 'Word': 'ఆల్దో'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'వి'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'స్టార్టెడ్'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'ఫ్రమ్'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'ఆంధ్రప్రదేశ్'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'ఎక్కడైతే'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'మా'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'కాలేజెస్'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'ఉన్నాయో'},
#  {'Sentence #': 'Sentence: 29', 'Word': ','},
#  {'Sentence #': 'Sentence: 29', 'Word': 'కాలేజెస్'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'నుంచి'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'వచ్చే'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'స్టూడెంట్స్'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'అన్ని'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'చోట్ల'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'నుంచి'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'ర్యాంక్స్'},
#  {'Sentence #': 'Sentence: 29', 'Word': 'సంపాదించారు'},
#  {'Sentence #': 'Sentence: 29', 'Word': '.'},
#  {'Sentence #': 'Sentence: 30', 'Word': '""'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ఈ'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'లెవల్లో'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'కాంపిటీషన్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'కూడా'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ఇంత'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'మంది'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'సౌత్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ఇండియా'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'నుంచి'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ఫస్ట్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 30', 'Word': ','},
#  {'Sentence #': 'Sentence: 30', 'Word': 'అలాగే'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'గర్ల్స్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ఆల్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ఇండియా'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ఫస్ట్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'ర్యాంక్'},
#  {'Sentence #': 'Sentence: 30', 'Word': ','},
#  {'Sentence #': 'Sentence: 30', 'Word': 'సెకండ్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'హ్యాండ్'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'తెప్పించడం'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'అన్నది'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'అద్భుతమైన'},
#  {'Sentence #': 'Sentence: 30', 'Word': 'విషయం'},
#  {'Sentence #': 'Sentence: 30', 'Word': '.'},
#  {'Sentence #': 'Sentence: 31', 'Word': '""'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'ఖచ్చితంగా'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'మేము'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'వేసే'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'ప్రణాళిక'},
#  {'Sentence #': 'Sentence: 31', 'Word': ','},
#  {'Sentence #': 'Sentence: 31', 'Word': 'మేం'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'పెట్టే'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'క్వాలిటీ'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'ఆఫ్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'టీచింగ్'},
#  {'Sentence #': 'Sentence: 31', 'Word': ','},
#  {'Sentence #': 'Sentence: 31', 'Word': 'మేము'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'చేసే'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'మానిటరింగ్'},
#  {'Sentence #': 'Sentence: 31', 'Word': ','},
#  {'Sentence #': 'Sentence: 31', 'Word': 'అలాగే'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'స్టూడెంట్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'కి'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'ఇచ్చే'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'సపోర్ట్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'సిస్టమ్'},
#  {'Sentence #': 'Sentence: 31', 'Word': ','},
#  {'Sentence #': 'Sentence: 31', 'Word': 'కౌన్సిల్లింగ్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'సపోర్ట్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'సిస్టమ్'},
#  {'Sentence #': 'Sentence: 31', 'Word': ','},
#  {'Sentence #': 'Sentence: 31', 'Word': 'అలాగే'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'దిశ'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'ప్రోగ్రాం'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'లాంచ్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'చేసి'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'మేము'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'స్టూడెంట్స్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'కి'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'ఈవెన్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'మెంటల్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'కౌన్సిలింగ్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'కూడా'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'ఇస్తున్నాం'},
#  {'Sentence #': 'Sentence: 31', 'Word': ','},
#  {'Sentence #': 'Sentence: 31', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'స్టూడెంట్స్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'స్ట్రెస్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'కి'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'లోనవకుండా'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'ఎప్పుడైనా'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'మార్క్స్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'తగ్గితే'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'దానికి'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'డిస్కరేజ్'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'కాకుండా'},
#  {'Sentence #': 'Sentence: 31', 'Word': 'ఇస్తాం'},
#  {'Sentence #': 'Sentence: 31', 'Word': '.'},
#  {'Sentence #': 'Sentence: 32', 'Word': '""'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'గత'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'ఏడాది'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'పది'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'ఓపెన్'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'అఖిలభారత'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'కోటాలో'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'కూడా'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'రాష్ట్రాలు'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'ప్రవేశించాయి'},
#  {'Sentence #': 'Sentence: 32', 'Word': ','},
#  {'Sentence #': 'Sentence: 32', 'Word': 'కాబట్టి'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'దాని'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'వల్ల'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'విద్యార్థులకు'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'లాభం'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'జరిగిందా'},
#  {'Sentence #': 'Sentence: 32', 'Word': ','},
#  {'Sentence #': 'Sentence: 32', 'Word': 'నష్టం'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'జరిగిందా'},
#  {'Sentence #': 'Sentence: 32', 'Word': '?'},
#  {'Sentence #': 'Sentence: 32', 'Word': '""'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'డెఫినైట్లీ'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'ఫర్'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'స్టూడెంట్స్'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'ఇట్స్'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'అడ్వాంటేజ్'},
#  {'Sentence #': 'Sentence: 32', 'Word': 'అండి'},
#  {'Sentence #': 'Sentence: 32', 'Word': '.'},
#  {'Sentence #': 'Sentence: 33', 'Word': '""'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'ఎందుకంటే'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'పిల్లలు'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'ఇన్'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'జనరల్'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'దే'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'ఆర్'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'వెరీ'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'హార్డ్'},
#  {'Sentence #': 'Sentence: 33', 'Word': 'వర్కింగ్'},
#  {'Sentence #': 'Sentence: 33', 'Word': '.'},
#  {'Sentence #': 'Sentence: 34', 'Word': '""'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'మీరు'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'ఒక'},
#  {'Sentence #': 'Sentence: 34', 'Word': '1997'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'టైమ్'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'తీసుకుంటే'},
#  {'Sentence #': 'Sentence: 34', 'Word': ','},
#  {'Sentence #': 'Sentence: 34', 'Word': 'హార్డ్లీ'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'హండ్రెడ్'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'లోపల'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'ఐఐటి'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'ఫైవ్'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'ర్యాంక్స్'},
#  {'Sentence #': 'Sentence: 34', 'Word': ','},
#  {'Sentence #': 'Sentence: 34', 'Word': 'సిక్స్'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'ర్యాంక్స్'},
#  {'Sentence #': 'Sentence: 34', 'Word': 'వచ్చేవి'},
#  {'Sentence #': 'Sentence: 34', 'Word': '.'},
#  {'Sentence #': 'Sentence: 35', 'Word': '""'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'అటువంటిది'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'నారాయణ'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'విద్యాసంస్థలు'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'అలా'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'కాదు'},
#  {'Sentence #': 'Sentence: 35', 'Word': ','},
#  {'Sentence #': 'Sentence: 35', 'Word': 'మన'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'పిల్లలు'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'హార్డ్'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'వర్క్'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'చేస్తారు'},
#  {'Sentence #': 'Sentence: 35', 'Word': ','},
#  {'Sentence #': 'Sentence: 35', 'Word': 'నార్త్'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'ఇండియన్'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'స్టూడెంట్స్'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'కే'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'ఎందుకు'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'రావాలి'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'అని'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'స్పెషల్'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'గా'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'ఐఐటీ'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'ప్రోగ్రాం'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'స్టార్ట్'},
#  {'Sentence #': 'Sentence: 35', 'Word': 'చేసాం'},
#  {'Sentence #': 'Sentence: 35', 'Word': '.'},
#  {'Sentence #': 'Sentence: 36', 'Word': '""'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'దాని'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'వలన'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'ఈరోజు'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'అల్మోస్ట్'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'ఫిఫ్టీన్'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'పర్సెంట్'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'వరకు'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'సీట్స్'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'అన్నవి'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'తెలుగు'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'విద్యార్థులే'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'బ్యాక్'},
#  {'Sentence #': 'Sentence: 36', 'Word': 'చేస్తున్నారు'},
#  {'Sentence #': 'Sentence: 36', 'Word': '.'},
#  {'Sentence #': 'Sentence: 37', 'Word': '""'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'డెఫినెట్'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'గా'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'ఈ'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'నేషనల్'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'పూల్'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'లోకి'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'వెళ్లడం'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'వల్ల'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'స్టూడెంట్స్'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'కి'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'చాలా'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'అడ్వాంటేజ్'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'అనేది'},
#  {'Sentence #': 'Sentence: 37', 'Word': 'ఉంటుంది'},
#  {'Sentence #': 'Sentence: 37', 'Word': '.'},
#  {'Sentence #': 'Sentence: 38', 'Word': '""'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'ఇది'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'అంటే'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'కష్టపడి'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'ప్రణాళికాబద్ధంగా'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'చదవడం'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'వల్ల'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'నీట్'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'ర్యాంకులు'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'సాధ్యమయ్యాయని'},
#  {'Sentence #': 'Sentence: 38', 'Word': ','},
#  {'Sentence #': 'Sentence: 38', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'ర్యాంకర్లు'},
#  {'Sentence #': 'Sentence: 38', 'Word': 'చెబుతున్నారు'},
#  {'Sentence #': 'Sentence: 38', 'Word': '.'},
#  {'Sentence #': 'Sentence: 39', 'Word': '""'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'అదే'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'విధంగా'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'భవిష్యత్తులో'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'ఏయిమ్స్'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'సీటు'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'కొట్టడమే'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'తమ'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'ప్రధాన'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'లక్ష్యమని'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'విద్యార్థులు'},
#  {'Sentence #': 'Sentence: 39', 'Word': 'చెబుతున్నారు'},
#  {'Sentence #': 'Sentence: 39', 'Word': '.'},
#  {'Sentence #': 'Sentence: 40', 'Word': '""'},
#  {'Sentence #': 'Sentence: 40', 'Word': 'కెమెరామెన్'},
#  {'Sentence #': 'Sentence: 40', 'Word': 'రమణ'},
#  {'Sentence #': 'Sentence: 40', 'Word': 'మహేష్'},
#  {'Sentence #': 'Sentence: 40', 'Word': 'తో'},
#  {'Sentence #': 'Sentence: 40', 'Word': 'నగేష్'},
#  {'Sentence #': 'Sentence: 40', 'Word': 'చారి'},
#  {'Sentence #': 'Sentence: 40', 'Word': 'ఈటీవీ'},
#  {'Sentence #': 'Sentence: 40', 'Word': 'న్యూస్'},
#  {'Sentence #': 'Sentence: 40', 'Word': 'హైదరాబాద్'},
#  {'Sentence #': 'Sentence: 40', 'Word': '.'},
#  {'Sentence #': 'Sentence: 41', 'Word': '""'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'హలో'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'హాయ్'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'నా'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'పేరు'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'శ్రావణి'},
#  {'Sentence #': 'Sentence: 41', 'Word': ','},
#  {'Sentence #': 'Sentence: 41', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'మేము'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'ఇక్కడ'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'చైనాలో'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'ఉంటున్నాము'},
#  {'Sentence #': 'Sentence: 41', 'Word': ','},
#  {'Sentence #': 'Sentence: 41', 'Word': 'చైనాలో'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'శాంగానే'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'స్టేట్'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'లో'},
#  {'Sentence #': 'Sentence: 41', 'Word': 'ఉంటున్నాము'},
#  {'Sentence #': 'Sentence: 41', 'Word': '.'},
#  {'Sentence #': 'Sentence: 42', 'Word': '""'},
#  {'Sentence #': 'Sentence: 42', 'Word': 'ఆ'},
#  {'Sentence #': 'Sentence: 42', 'Word': 'నేను'},
#  {'Sentence #': 'Sentence: 42', 'Word': 'మెయిన్'},
#  {'Sentence #': 'Sentence: 42', 'Word': 'గా'},
#  {'Sentence #': 'Sentence: 42', 'Word': 'ఈ'},
#  {'Sentence #': 'Sentence: 42', 'Word': 'వీడియో'},
#  {'Sentence #': 'Sentence: 42', 'Word': 'చేయడానికి'},
#  {'Sentence #': 'Sentence: 42', 'Word': 'రీసన్'},
#  {'Sentence #': 'Sentence: 42', 'Word': 'ఏంటి'},
#  ...]

# %%
result = nb.predict(X_t)
s = 'Sentence: 1'
done = []
new = open('result.tsv', 'w')
for i, record in enumerate(test.to_dict('records')):
    sent = record['Sentence #']
    word = record['Word']
    tag  = result[i]

    if word in filler_train:
        tag = 'B-filler_R'
    if word in pet_train:
        tag = 'B-pet_R'

        
    if word == '""':
        new.write('""'+'\n')
    else:
        new.write(word+'\t'+tag+'\n')
    #print(record['Word'], result[i])

# %%
len(test.to_dict('records'))
# Out:
# 10239
